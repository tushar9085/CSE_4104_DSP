# %%
#Signal Correlation
# known signal thakbe ekta
# arekta live signal
# then decision correlation er maddhome
# duita signal er moddhe kotota shomporko sheta ber kore

# Two types of correlation - auto and cross

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
#Define the function for auto correlation
def auto_correlation(signal):
  corr = np.correlate(signal, signal, mode = 'full')
  return corr[len(corr)//2:]

#Define the function for Cross correlation
def cross_correlation(signal1, signal2):
  corr = np.correlate(signal1, signal2, mode = 'full')
  return corr[len(corr)//2:]

#Define Signal
signal1 = np.array([1, 2, 305, 4, 5])
signal2 = np.array([20, 4, 60, 8, 1005])

#compute the correlation
auto_corr = auto_correlation(signal1)
cross_corr = cross_correlation(signal1, signal2)

print(auto_corr)
print(cross_corr)
# Out:
# [93071  1852  1838    14     5]
# [23385  1540  6416   100   100]

# %%
#plotting the input signals
(fig, (ax1, ax2)) = plt.subplots(2, 1, figsize=(10, 6))
ax1.plot(signal1)
ax2.plot(signal2)
plt.show()

# %%
#plot the correlated signals

(fig, (ax1, ax2)) = plt.subplots(2, 1, figsize=(10, 6))
ax1.plot(auto_corr)
ax1.set_title("Auto Corelated signal")

ax2.plot(cross_corr)
ax2.set_title("Cross Corelated signal")

plt.show()

# %% [markdown]
# Work
# ==========
# Ekta complex boro signal nite hobe sinusoidal or exponential
# minimum 500 ta sample thakte hobe
# then tader moddhe correlation
